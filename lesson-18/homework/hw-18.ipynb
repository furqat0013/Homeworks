# %%
import pandas as pd
df = pd.read_csv('tackoverflow_qa.csv')
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0   332289  2008-12-01 21:24:44   3184    5962784
# 1  2051744  2010-01-12 19:31:47    420     587728
# 2  2225995  2010-02-09 00:51:38     51      59922
# 3  5486226  2011-03-30 12:26:50      7       6393
# 4  5515021  2011-04-01 14:50:44     10      13744
#
#                                                title  answercount  \
# 0  How do I change the size of figures drawn with...           14
# 1                      How to invert the x or y axis           10
# 2               How can I create stacked line graph?            4
# 3                           Rolling median in python            5
# 4       Compute a compounded return series in Python            3
#
#    commentcount  favoritecount       quest_name  quest_rep         ans_name  \
# 0             1            0.0        tatwright    37837.0              NaN
# 1             3            0.0          DarkAnt     4211.0          Demitri
# ...

# %%
first = df['title'][df['creationdate'] < '2014-01-01']   
first
# Out:
# 0       How do I change the size of figures drawn with...
# 1                           How to invert the x or y axis
# 2                    How can I create stacked line graph?
# 3                                Rolling median in python
# 4            Compute a compounded return series in Python
#                               ...
# 4597    Out of memory when DataFrame.resample() is cal...
# 4598    How to avoid pandas creating an index in a sav...
# 4604    Python/Pandas DataFrame 1st line issue with da...
# 4608                   Hourly frequency count with Python
# 4757            Parsing a non regular text file in pandas
# Name: title, Length: 3805, dtype: object

# %%
second = df['title'][df['score'] > 50]
second
# Out:
# 0       How do I change the size of figures drawn with...
# 1                           How to invert the x or y axis
# 2                    How can I create stacked line graph?
# 7         Improve subplot size/spacing with many subplots
# 12      What is the most efficient way to loop through...
#                               ...
# 9264    Counting non zero values in each column of a D...
# 9343                        Pandas groupby month and year
# 9369    How do I get the name of the rows from the ind...
# 9373    Replacing few values in a pandas dataframe col...
# 9414    why should I make a copy of a data frame in pa...
# Name: title, Length: 702, dtype: object

# %%
third = df['title'][df['score'].between(50, 100)]
third
# Out:
# 2                    How can I create stacked line graph?
# 42                 join or merge with overwrite in pandas
# 65                 python-pandas and databases like mysql
# 86      Redefining the Index in a Pandas DataFrame object
# 98              Specifying data type in Pandas csv reader
#                               ...
# 9234          Find empty or NaN entry in Pandas Dataframe
# 9241    ImportError HDFStore requires PyTables No modu...
# 9261                      Drop multiple columns in pandas
# 9264    Counting non zero values in each column of a D...
# 9369    How do I get the name of the rows from the ind...
# Name: title, Length: 306, dtype: object

# %%
fourth = df['title'][df['ans_name'] == 'Scott Boston']
fourth
# Out:
# 5392    Pandas dataframe with multiindex column - merg...
# Name: title, dtype: object

# %%
fifth = df['title'][df['ans_name'].isin(['Scott Boston', 'Demitri', 'Mike Pennington', 'Jim', 'doug'])]
fifth
# Out:
# 1                           How to invert the x or y axis
# 2                    How can I create stacked line graph?
# 3                                Rolling median in python
# 4            Compute a compounded return series in Python
# 5392    Pandas dataframe with multiindex column - merg...
# 9461    Pandas DataFrame Assignment Issue - Possible Bug?
# Name: title, dtype: object

# %%
sixth = df['title'][df['creationdate'].between('2014-03-01', '2014-10-31') & (df['ans_name'] == 'Unutbu') & (df['score'] < 5)]
sixth
# Out:
# Series([], Name: title, dtype: object)

# %%
seventh = df['title'][df['score'].between(5,10) | (df['viewcount'] > 10000)]
seventh
# Out:
# 0       How do I change the size of figures drawn with...
# 1                           How to invert the x or y axis
# 2                    How can I create stacked line graph?
# 3                                Rolling median in python
# 4            Compute a compounded return series in Python
#                               ...
# 9401    Intersection of two pandas dataframes based on...
# 9404            Set pandas datetime index one day forward
# 9406    Pandas: get second character of the string, fr...
# 9414    why should I make a copy of a data frame in pa...
# 9427    sql select group by a having count(1) > 1 equi...
# Name: title, Length: 2949, dtype: object

# %%
eighth = df['title'][df['ans_name'] != 'Scott Boston']
eighth
# Out:
# 0       How do I change the size of figures drawn with...
# 1                           How to invert the x or y axis
# 2                    How can I create stacked line graph?
# 3                                Rolling median in python
# 4            Compute a compounded return series in Python
#                               ...
# 9458       drop_duplicates() in Pandas Based on Condition
# 9459    Replace a whole dataframe with another (overwr...
# 9460    Extract indices of cells meeting criteria from...
# 9461    Pandas DataFrame Assignment Issue - Possible Bug?
# 9462          Python- Pandas - date time index type error
# Name: title, Length: 9462, dtype: object

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t1 = titanic_df[(titanic_df['Sex'] == 'female') & (titanic_df['Pclass'] == 1) & (titanic_df['Age'].between(20, 30))]
t1
# Out:
#      PassengerId  Survived  Pclass  \
# 88            89         1       1
# 151          152         1       1
# 257          258         1       1
# 290          291         1       1
# 309          310         1       1
# 310          311         1       1
# 341          342         1       1
# 356          357         1       1
# 369          370         1       1
# 393          394         1       1
# 498          499         0       1
# 520          521         1       1
# 537          538         1       1
# 539          540         1       1
# 627          628         1       1
# 641          642         1       1
# 708          709         1       1
# 710          711         1       1
# 730          731         1       1
# 742          743         1       1
# 842          843         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 88                         Fortune, Miss. Mabel Helen  female  23.0      3
# ...

# %%
t2 = titanic_df[titanic_df['Fare'] > 100]
t2
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
t3 = titanic_df[(titanic_df['Survived'] == 1) & (titanic_df['SibSp'] == 0) & (titanic_df['Parch'] == 0)]
t3
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 875          876         1       3
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t4 = titanic_df[(titanic_df['Embarked'] == 'C') & (titanic_df['Fare'] > 50)]
t4
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# 54            55         0       1
# ..           ...       ...     ...
# 742          743         1       1
# 789          790         0       1
# 835          836         1       1
# 849          850         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t5 = titanic_df[(titanic_df['SibSp'] > 0) & (titanic_df['Parch'] > 0)]
t5
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 869          870         1       3
# 871          872         1       1
# 888          889         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# ..                                                ...     ...   ...    ...
# ...

# %%
t6 = titanic_df[(titanic_df['Age'] <= 15) & (titanic_df['Survived'] == 0)]
t6
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 111          112         0       3                     Zabour, Miss. Hileni
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 147          148         0       3         Ford, Miss. Robina Maggie "Ruby"
# 164          165         0       3             Panula, Master. Eino Viljami
# ...

# %%
t7 = titanic_df[(titanic_df['Cabin'].notnull()) & (titanic_df['Fare'] > 200)]
t7
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 438          439         0       1
# 527          528         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# ...

# %%
t8 = titanic_df[titanic_df['PassengerId'] % 2 == 1]
t8
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t9 = titanic_df[titanic_df['Ticket'].duplicated(keep=False) == False]
t9
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t10 = titanic_df[(titanic_df['Sex'] == 'female') & (titanic_df['Pclass'] == 1) & (titanic_df['Name'].str.contains('Miss'))]
t10
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 11            12         1       1               Bonnell, Miss. Elizabeth
# 61            62         1       1                    Icard, Miss. Amelie
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 136          137         1       1           Newsom, Miss. Helen Monypeny
# 177          178         0       1             Isham, Miss. Ann Elizabeth
# 195          196         1       1                   Lurette, Miss. Elise
# 215          216         1       1                Newell, Miss. Madeleine
# 218          219         1       1                  Bazzani, Miss. Albina
# 257          258         1       1                   Cherry, Miss. Gladys
# 258          259         1       1                       Ward, Miss. Anna
# 269          270         1       1                 Bissette, Miss. Amelia
# 275          276         1       1      Andrews, Miss. Kornelia Theodosia
# ...
